# %%
import pandas as pd
import numpy as np
import sklearn as sk
print 'pandas version: ',pd.__version__
print 'numpy version:',np.__version__
print 'sklearn version:',sk.__version__
# Out:
# pandas version:  0.13.1
# numpy version: 1.8.1
# sklearn version: 0.14.1

# %%
import sys
home_dir='/home/ubuntu/UCSD_BigData'
sys.path.append(home_dir+'/utils')
from find_waiting_flow import *
from AWS_keypair_management import *

# %%
# %%writefile mr_weather.py
#!/usr/bin/python
"""
count the number of measurements of each type
"""
import sys
sys.path.append('/usr/lib/python2.6/dist-packages')
from mrjob.job import MRJob
import re
from sys import stderr

class MRWeather(MRJob):

    def mapper(self, _, line):
        try:
            self.increment_counter('MrJob Counters','mapper-all',1)
            elements=line.split(',')
            if elements[0]=='station':
                out=('header',1)
            else:
                out=(elements[0],1)
        except Exception, e:
            stderr.write('Error in line:\n'+line)
            stderr.write(e)
            self.increment_counter('MrJob Counters','mapper-error',1)
            out=('error',1)

        finally:
            yield out
            
    def combiner(self, word, counts):
        self.increment_counter('MrJob Counters','combiner',1)
        yield (word, sum(counts))
        #l_counts=[c for c in counts]  # extract list from iterator
        #S=sum(l_counts)
        #logfile.write('combiner '+word+' ['+','.join([str(c) for c in l_counts])+']='+str(S)+'\n')
        #yield (word, S)

    def reducer(self, word, counts):
        self.increment_counter('MrJob Counters','reducer',1)
        yield (word, sum(counts))
        #l_counts=[c for c in counts]  # extract list from iterator
        #S=sum(l_counts)
        #logfile.write('reducer '+word+' ['+','.join([str(c) for c in l_counts])+']='+str(S)+'\n')
        #yield (word, S)

if __name__ == '__main__':
    MRWeather.run()
# Out:
# Overwriting mr_weather.py

# %% [markdown]
# ## Running job inline

# %%
local_data='/home/ubuntu/UCSD_BigData/data/weather/ALL.head.csv'
# !ls -l $local_data
# Out:
# -rw-rw-r-- 1 ubuntu ubuntu 858960 May 19 03:42 /home/ubuntu/UCSD_BigData/data/weather/ALL.head.csv

# %%
# !python mr_weather.py $local_data > counts
# Out:
# using configs in /home/ubuntu/.mrjob.conf
# creating tmp directory /tmp/mr_weather.ubuntu.20140526.180453.701474
# writing to /tmp/mr_weather.ubuntu.20140526.180453.701474/step-0-mapper_part-00000
# Counters from step 1:
#   MrJob Counters:
#     combiner: 11
#     mapper-all: 999
# writing to /tmp/mr_weather.ubuntu.20140526.180453.701474/step-0-mapper-sorted
# > sort /tmp/mr_weather.ubuntu.20140526.180453.701474/step-0-mapper_part-00000
# writing to /tmp/mr_weather.ubuntu.20140526.180453.701474/step-0-reducer_part-00000
# Counters from step 1:
#   MrJob Counters:
#     combiner: 11
#     mapper-all: 999
#     reducer: 11
# Moving /tmp/mr_weather.ubuntu.20140526.180453.701474/step-0-reducer_part-00000 -> /tmp/mr_weather.ubuntu.20140526.180453.701474/output/part-00000
# Streaming final output from /tmp/mr_weather.ubuntu.20140526.180453.701474/output
# removing tmp directory /tmp/mr_weather.ubuntu.20140526.180453.701474

# %% [markdown]
# ## managing AWS Credentials ##
# The full details on how to get the credentials set up is given here: https://docs.google.com/document/d/1xDUy4ZI2yr1eCCRQ4ynWHsctbEb7ySHrSynBu0bxupU/edit?usp=sharing

# %%
import pickle
Creds= pickle.load(open('/home/ubuntu/Vault/Creds.pkl','rb'))
print Creds.keys()
print Creds['mrjob'].keys()
pair=Creds['mrjob']
key_id=pair['key_id']
secret_key=pair['secret_key']
ID=pair['ID']
s3_logs=pair['s3_logs']
print ID,key_id,s3_logs
# Out:
# ['launcher', 'mrjob']
# ['key_id', 'secret_key', 's3_logs', 'ID', 's3_scratch']
# jiz173 AKIAJQHZ25DAT5YYWY5Q s3://jiz173/logs

# %% [markdown]
# ###Checking for an available job flow###
# Before submitting your job for execution you need to find out which job flows are active and waiting. THe following cell will do that for you. If there is a waiting cluster, it will put it's ID into the variable `job_flow_id`

# %%
job_flow_id=find_waiting_flow(key_id,secret_key)
job_flow_id
# Out:
# <boto.emr.emrobject.JobFlow object at 0x3351650> no_script.yoavfreund.20140525.174308.746673 j-LTOJMJ14G840 WAITING
# <boto.emr.emrobject.JobFlow object at 0x369b910> no_script.yoavfreund.20140525.194233.003342 j-2KCJE554SGITB WAITING
# <boto.emr.emrobject.JobFlow object at 0x382d390> no_script.yoavfreund.20140526.014348.966938 j-6T8VIKMY8RHX WAITING
# u'j-6T8VIKMY8RHX'

# %% [markdown]
# ### Setting up the mrjob configuration file ###
# The last step before submitting the job is to insert the credentials into the file `/home/ubuntu/UCSD_BigData/utils/mrjob.conf.template` and put the result in the default location for the mrjob configuration file which is: `/home/ubuntu/.mrjob.conf`
# this is done by the following line. If the return value is `True` you are good to go. If it is `False` something went wrong and you should get an error message.
#
# The template file should work as is. However, feel free to change and add fields to this configuration file to make it your own.
#
# This step needs to be done just one time. Redone only when starting a new EC2 instance or if the credentials changed.
# It is better to do it in an interactive shell, rather than in a notebook. Here it is done in the notebook for demonstration purpose.

# %%
# %cd /home/ubuntu/UCSD_BigData/utils/
#!python Make.mrjob.conf.py
# %cd ../notebooks/weather.mapreduce/
# Out:
# /home/ubuntu/UCSD_BigData/utils
# /home/ubuntu/UCSD_BigData/notebooks/weather.mapreduce

# %%
# !python mr_weather.py -r emr --emr-job-flow-id  $job_flow_id  $local_data > counts
# Out:
# using configs in /home/ubuntu/.mrjob.conf
# creating new scratch bucket mrjob-e83818875103f838
# using s3://mrjob-e83818875103f838/tmp/ as our scratch dir on S3
# creating tmp directory /tmp/mr_weather.ubuntu.20140526.180512.460820
# creating S3 bucket 'mrjob-e83818875103f838' to use as scratch space
# Copying non-input files into s3://mrjob-e83818875103f838/tmp/mr_weather.ubuntu.20140526.180512.460820/files/
# Adding our job to existing job flow j-6T8VIKMY8RHX
# Job launched 30.4s ago, status RUNNING: Running step (mr_weather.ubuntu.20140526.180512.460820: Step 1 of 1)
# Job launched 60.8s ago, status RUNNING: Running step (mr_weather.ubuntu.20140526.180512.460820: Step 1 of 1)
# Job launched 91.1s ago, status RUNNING: Running step (mr_weather.ubuntu.20140526.180512.460820: Step 1 of 1)
# Job completed.
# Running time was 67.0s (not counting time spent waiting for the EC2 instances)
# ec2_key_pair_file not specified, going to S3
# Fetching counters from S3...
# Waiting 5.0s for S3 eventual consistency
# Counters may not have been uploaded to S3 yet. Try again in 5 minutes with: mrjob fetch-logs --counters j-6T8VIKMY8RHX
# Counters from step 1:
#   (no counters found)
# Streaming final output from s3://mrjob-e83818875103f838/tmp/mr_weather.ubuntu.20140526.180512.460820/output/
# removing tmp directory /tmp/mr_weather.ubuntu.20140526.180512.460820
# Removing all files in s3://mrjob-e83818875103f838/tmp/mr_weather.ubuntu.20140526.180512.460820/

# %%
# !python mr_weather.py -r emr --emr-job-flow-id $job_flow_id hdfs:/weather/weather.csv > counts
# Out:
# using configs in /home/ubuntu/.mrjob.conf
# creating new scratch bucket mrjob-2664a0d34e30c640
# using s3://mrjob-2664a0d34e30c640/tmp/ as our scratch dir on S3
# creating tmp directory /tmp/mr_weather.ubuntu.20140526.180723.765932
# creating S3 bucket 'mrjob-2664a0d34e30c640' to use as scratch space
# Copying non-input files into s3://mrjob-2664a0d34e30c640/tmp/mr_weather.ubuntu.20140526.180723.765932/files/
# Adding our job to existing job flow j-6T8VIKMY8RHX
# Job launched 30.4s ago, status RUNNING: Running step (mr_weather.ubuntu.20140526.180723.765932: Step 1 of 1)
# Job launched 60.7s ago, status RUNNING: Running step (mr_weather.ubuntu.20140526.180723.765932: Step 1 of 1)
# Job launched 91.1s ago, status RUNNING: Running step (mr_weather.ubuntu.20140526.180723.765932: Step 1 of 1)
# Job launched 121.5s ago, status RUNNING: Running step (mr_weather.ubuntu.20140526.180723.765932: Step 1 of 1)
# Job launched 151.8s ago, status RUNNING: Running step (mr_weather.ubuntu.20140526.180723.765932: Step 1 of 1)
# Job completed.
# Running time was 138.0s (not counting time spent waiting for the EC2 instances)
# ec2_key_pair_file not specified, going to S3
# Fetching counters from S3...
# Waiting 5.0s for S3 eventual consistency
# Counters may not have been uploaded to S3 yet. Try again in 5 minutes with: mrjob fetch-logs --counters j-6T8VIKMY8RHX
# Counters from step 1:
#   (no counters found)
# Streaming final output from s3://mrjob-2664a0d34e30c640/tmp/mr_weather.ubuntu.20140526.180723.765932/output/
# removing tmp directory /tmp/mr_weather.ubuntu.20140526.180723.765932
# Removing all files in s3://mrjob-2664a0d34e30c640/tmp/mr_weather.ubuntu.20140526.180723.765932/

# %%
# !cat counts
# Out:
# "AJ000037668"	28
# "AJ000037679"	29
# "AJ000037734"	56
# "AJ000037756"	105
# "AJ000037844"	110
# "AJ000037866"	85
# "AJ000037888"	27
# "AJ000037899"	94
# "AJ000037907"	154
# "AM000037627"	52
# "AM000037704"	76
# "AM000037773"	45
# "AM000037872"	31
# "AQC00914873"	95
# "AR000000004"	20
# "AR000000015"	20
# "AR000087270"	147
# "AR000087344"	167
# "AR000087418"	156
# "AR000087715"	178
# "AR000087803"	176
# "AR000870470"	98
# "ASN00001000"	34
# "ASN00001008"	25
# "ASN00001011"	4
# "ASN00001019"	45
# "ASN00001022"	10
# "ASN00002001"	141
# "ASN00002009"	108
# "ASN00002012"	227
# "ASN00002023"	97
# "ASN00002034"	6
# "ASN00002056"	149
# "ASN00002067"	31
# "ASN00002070"	1
# "ASN00003002"	211
# "ASN00003013"	63
# "ASN00003024"	72
# "ASN00003035"	28
# "ASN00003046"	20
# "ASN00003057"	197
# "ASN00003060"	8
# "ASN00003068"	64
# "ASN00003079"	34
# "ASN00003082"	25
# "ASN00003093"	48
# "ASN00004003"	73
# "ASN00004014"	42
# "ASN00004025"	70
# "ASN00004036"	110
# "ASN00004047"	56
# "ASN00004050"	13
# "ASN00004058"	8
# "ASN00004061"	45
# "ASN00004069"	18
# "ASN00004072"	2
# "ASN00004083"	89
# "ASN00004094"	16
# "ASN00004102"	9
# "ASN00005004"	109
# "ASN00005015"	151
# "ASN00005026"	190
# "ASN00005037"	19
# "ASN00005040"	109
# "ASN00005048"	92
# "ASN00005051"	67
# "ASN00005059"	2
# "ASN00005073"	52
# "ASN00005084"	55
# "ASN00005095"	22
# "ASN00006005"	138
# "ASN00006016"	17
# "ASN00006027"	107
# "ASN00006030"	128
# "ASN00031052"	222
# "ASN00031063"	38
# "ASN00031074"	5
# "ASN00031085"	130
# "ASN00031096"	7
# "ASN00031104"	99
# "ASN00031115"	95
# "ASN00031126"	4
# "ASN00031137"	15
# "ASN00031140"	154
# "ASN00031148"	6
# "ASN00031151"	11
# "ASN00031162"	28
# "ASN00031184"	13
# "ASN00031195"	26
# "ASN00031203"	60
# "ASN00032006"	36
# "ASN00032017"	18
# "ASN00032020"	13
# "ASN00032028"	103
# "ASN00032031"	215
# "ASN00032039"	20
# "ASN00032042"	202
# "ASN00032053"	15
# "ASN00032064"	122
# "ASN00032075"	42
# "ASN00032086"	103
# "ASN00032097"	49
# "ASN00032105"	98
# "ASN00032130"	20
# "ASN00032138"	46
# "ASN00032141"	103
# "ASN00032152"	13
# "ASN00032163"	13
# "ASN00032174"	13
# "ASN00032185"	13
# "ASN00033007"	150
# "ASN00033010"	148
# "ASN00033018"	76
# "ASN00033021"	195
# "ASN00033029"	45
# "ASN00033032"	229
# "ASN00033043"	81
# "ASN00033054"	257
# "ASN00033065"	347
# "ASN00033076"	207
# "ASN00033087"	193
# "ASN00033090"	147
# "ASN00033098"	52
# "ASN00033106"	47
# "ASN00033117"	26
# "ASN00033120"	31
# "ASN00033128"	46
# "ASN00033131"	24
# "ASN00033139"	87
# "ASN00033142"	17
# "ASN00033153"	77
# "ASN00033175"	80
# "ASN00033186"	63
# "ASN00033197"	129
# "ASN00033205"	74
# "ASN00033216"	7
# "ASN00033227"	65
# "ASN00033230"	4
# "ASN00033249"	6
# "ASN00033252"	18
# "ASN00033263"	13
# "ASN00033285"	13
# "ASN00033296"	62
# "ASN00033304"	13
# "ASN00033315"	2
# "ASN00034000"	227
# "ASN00034008"	53
# "ASN00034011"	49
# "ASN00034019"	26
# "ASN00034022"	124
# "ASN00034033"	14
# "ASN00034044"	65
# "ASN00034055"	63
# "ASN00034077"	36
# "ASN00034080"	85
# "ASN00034091"	1
# "ASN00034099"	40
# "ASN00035001"	195
# "ASN00035009"	179
# "ASN00035012"	174
# "ASN00035023"	31
# "ASN00035034"	64
# "ASN00035045"	65
# "ASN00035056"	193
# "ASN00035067"	59
# "ASN00035070"	322
# "ASN00035078"	76
# "ASN00035081"	149
# "ASN00035089"	10
# "ASN00035092"	39
# "ASN00035100"	15
# "ASN00035108"	11
# "ASN00035111"	57
# "ASN00035119"	93
# "ASN00035122"	87
# "ASN00035133"	5
# "ASN00035155"	6
# "ASN00035166"	4
# "ASN00035177"	41
# "ASN00035180"	101
# "ASN00035188"	103
# "ASN00035191"	65
# "ASN00035199"	99
# "ASN00035207"	61
# "ASN00035210"	5
# "ASN00035218"	52
# "ASN00035221"	61
# "ASN00035232"	42
# "ASN00035243"	6
# "ASN00035254"	14
# "ASN00035265"	58
# "ASN00035287"	3
# "ASN00035290"	107
# "ASN00036002"	119
# "ASN00036013"	124
# "ASN00036024"	152
# "ASN00036035"	66
# "ASN00036046"	203
# "ASN00036057"	32
# "ASN00036060"	30
# "ASN00036068"	55
# "ASN00036071"	67
# "ASN00043097"	49
# "ASN00043105"	13
# "ASN00044007"	137
# "ASN00044010"	324
# "ASN00044018"	91
# "ASN00044021"	230
# "ASN00044029"	109
# "ASN00044032"	157
# "ASN00044043"	52
# "ASN00044054"	108
# "ASN00044065"	118
# "ASN00044076"	151
# "ASN00044087"	19
# "ASN00044090"	26
# "ASN00044106"	17
# "ASN00044120"	122
# "ASN00044128"	47
# "ASN00044131"	73
# "ASN00044139"	50
# "ASN00044142"	151
# "ASN00044153"	33
# "ASN00044164"	19
# "ASN00044175"	55
# "ASN00044186"	16
# "ASN00044205"	11
# "ASN00044216"	15
# "ASN00045000"	146
# "ASN00045008"	89
# "ASN00045011"	129
# "ASN00045019"	46
# "ASN00045022"	96
# "ASN00045033"	3
# "ASN00045044"	5
# "ASN00045055"	2
# "ASN00045066"	32
# "ASN00046001"	58
# "ASN00046009"	22
# "ASN00046012"	39
# "ASN00046023"	63
# "ASN00046034"	99
# "ASN00046045"	22
# "ASN00046056"	48
# "ASN00046067"	67
# "ASN00046070"	20
# "ASN00046078"	45
# "ASN00046081"	19
# "ASN00046089"	35
# "ASN00046092"	7
# "ASN00046100"	23
# "ASN00046108"	7
# "ASN00046111"	5
# "ASN00046119"	11
# "ASN00046122"	10
# "ASN00047002"	92
# "ASN00047013"	144
# "ASN00047024"	147
# "ASN00047035"	61
# "ASN00047046"	130
# "ASN00047057"	67
# "ASN00047060"	47
# "ASN00047068"	12
# "ASN00047071"	52
# "ASN00047079"	53
# "ASN00047082"	73
# "ASN00047093"	132
# "ASN00048003"	75
# "ASN00048014"	154
# "ASN00048025"	112
# "ASN00048036"	180
# "ASN00048047"	143
# "ASN00048050"	5
# "ASN00048058"	55
# "ASN00048061"	116
# "ASN00048069"	75
# "ASN00048072"	148
# "ASN00048083"	48
# "ASN00048094"	25
# "ASN00048102"	14
# "ASN00048113"	29
# "ASN00048124"	50
# "ASN00048135"	12
# "ASN00048146"	16
# "ASN00048157"	22
# "ASN00048160"	36
# "ASN00048168"	142
# "ASN00048171"	38
# "ASN00048179"	4
# "ASN00048182"	28
# "ASN00048193"	35
# "ASN00048201"	33
# "ASN00048209"	12
# "ASN00048245"	69
# "ASN00049004"	154
# "ASN00049015"	54
# "ASN00049026"	79
# "ASN00049037"	124
# "ASN00049040"	18
# "ASN00049048"	133
# "ASN00049051"	37
# "ASN00049059"	60
# "ASN00049062"	11
# "ASN00049073"	17
# "ASN00049084"	30
# "ASN00049095"	17
# "ASN00049103"	58
# "ASN00049114"	22
# "ASN00050002"	92
# "ASN00050013"	57
# "ASN00050024"	51
# "ASN00050035"	267
# "ASN00050046"	55
# "ASN00050057"	5
# "ASN00050060"	14
# "ASN00050068"	37
# "ASN00050071"	24
# "ASN00050079"	40
# "ASN00050082"	24
# "ASN00050093"	31
# "ASN00050101"	46
# "ASN00050109"	17
# "ASN00050112"	65
# "ASN00050123"	35
# "ASN00051003"	68
# "ASN00051014"	154
# "ASN00051025"	151
# "ASN00051036"	48
# "ASN00051047"	33
# "ASN00057012"	79
# "ASN00057023"	154
# "ASN00057034"	60
# "ASN00057045"	91
# "ASN00057056"	7
# "ASN00057067"	46
# "ASN00057078"	7
# "ASN00057089"	28
# "ASN00057092"	22
# "ASN00057100"	25
# "ASN00057119"	102
# "ASN00057122"	2
# "ASN00058002"	124
# "ASN00058013"	120
# "ASN00058024"	106
# "ASN00058035"	67
# "ASN00058046"	63
# "ASN00058057"	110
# "ASN00058060"	167
# "ASN00058068"	12
# "ASN00058071"	51
# "ASN00058079"	12
# "ASN00058082"	33
# "ASN00058093"	78
# "ASN00058101"	4
# "ASN00058109"	171
# "ASN00058112"	3
# "ASN00058123"	6
# "ASN00058134"	21
# "ASN00058145"	11
# "ASN00058156"	126
# "ASN00058167"	13
# "ASN00058189"	8
# "ASN00058192"	109
# "ASN00058208"	54
# "ASN00058211"	53
# "ASN00058219"	40
# "ASN00058222"	9
# "ASN00059003"	94
# "ASN00059014"	37
# "ASN00059025"	13
# "ASN00059036"	33
# "ASN00059047"	137
# "ASN00059050"	34
# "ASN00059058"	1
# "ASN00059061"	36
# "ASN00059069"	42
# "ASN00059072"	34
# "ASN00059083"	5
# "ASN00059094"	16
# "ASN00059102"	10
# "ASN00059113"	63
# "ASN00059124"	10
# "ASN00059135"	12
# "ASN00060001"	47
# "ASN00060009"	55
# "ASN00060012"	114
# "ASN00060023"	215
# "ASN00060034"	93
# "ASN00060045"	19
# "ASN00060056"	68
# "ASN00060067"	53
# "ASN00060070"	26
# "ASN00060078"	5
# "ASN00060081"	98
# "ASN00060089"	36
# "ASN00060092"	136
# "ASN00060100"	2
# "ASN00060122"	59
# "ASN00060144"	60
# "ASN00061002"	242
# "ASN00061013"	71
# "ASN00061024"	270
# "ASN00061035"	132
# "ASN00061046"	294
# "ASN00061057"	76
# "ASN00061060"	64
# "ASN00061068"	77
# "ASN00061071"	322
# "ASN00061079"	218
# "ASN00061082"	210
# "ASN00061093"	168
# "ASN00061101"	23
# "ASN00061109"	35
# "ASN00061112"	10
# "ASN00061134"	19
# "ASN00061145"	5
# "ASN00061167"	25
# "ASN00061170"	102
# "ASN00061181"	40
# "ASN00061189"	40
# "ASN00061192"	105
# "ASN00061200"	55
# "ASN00061208"	11
# "ASN00061211"	129
# "ASN00061219"	17
# "ASN00061222"	129
# "ASN00061233"	15
# "ASN00061244"	26
# "ASN00061255"	54
# "ASN00061280"	23
# "ASN00061288"	224
# "ASN00061291"	5
# "ASN00061299"	68
# "ASN00061307"	7
# "ASN00061310"	53
# "ASN00061318"	101
# "ASN00061321"	1
# "ASN00061329"	127
# "ASN00061332"	9
# "ASN00061354"	46
# "ASN00061365"	79
# "ASN00061376"	62
# "ASN00061387"	50
# "ASN00061390"	105
# "ASN00061406"	9
# "ASN00062003"	97
# "ASN00062014"	145
# "ASN00062025"	75
# "ASN00062036"	128
# "ASN00062047"	2
# "ASN00062050"	28
# "ASN00062058"	8
# "ASN00062061"	13
# "ASN00062069"	43
# "ASN00062072"	13
# "ASN00062083"	18
# "ASN00062102"	55
# "ASN00063004"	573
# "ASN00063026"	59
# "ASN00063037"	134
# "ASN00063040"	76
# "ASN00063048"	96
# "ASN00063051"	49
# "ASN00063059"	33
# "ASN00063062"	159
# "ASN00063073"	253
# "ASN00063084"	79
# "ASN00063095"	43
# "ASN00063103"	30
# "ASN00063114"	32
# "ASN00063125"	82
# "ASN00063136"	174
# "ASN00063147"	26
# "ASN00063150"	25
# "ASN00063158"	63
# "ASN00063161"	15
# "ASN00063172"	42
# "ASN00063183"	29
# "ASN00063194"	17
# "ASN00063202"	38
# "ASN00063213"	9
# "ASN00063224"	295
# "ASN00063235"	11
# "ASN00063246"	100
# "ASN00063271"	74
# "ASN00063279"	15
# "ASN00063293"	126
# "ASN00063301"	79
# "ASN00064016"	76
# "ASN00064027"	11
# "ASN00064038"	26
# "ASN00064041"	100
# "ASN00064049"	22
# "ASN00065006"	357
# "ASN00065017"	66
# "ASN00065020"	278
# "ASN00065028"	73
# "ASN00065031"	58
# "ASN00065039"	58
# "ASN00065042"	25
# "ASN00065075"	31
# "ASN00065097"	2
# "ASN00065105"	23
# "ASN00066007"	147
# "ASN00066010"	127
# "ASN00066018"	123
# "ASN00066021"	72
# "ASN00066029"	25
# "ASN00066032"	63
# "ASN00066054"	87
# "ASN00066065"	61
# "ASN00066076"	89
# "ASN00066087"	83
# "ASN00066090"	46
# "ASN00066098"	69
# "ASN00066106"	8
# "ASN00066117"	4
# "ASN00066120"	209
# "ASN00066128"	91
# "ASN00066131"	264
# "ASN00066139"	28
# "ASN00066142"	89
# "ASN00066153"	161
# "ASN00066164"	170
# "ASN00066175"	7
# "ASN00066205"	32
# "ASN00067000"	17
# "ASN00067008"	58
# "ASN00067011"	30
# "ASN00067019"	284
# "ASN00067022"	51
# "ASN00067033"	165
# "ASN00067044"	29
# "ASN00067055"	65
# "ASN00067080"	73
# "ASN00067088"	39
# "ASN00067091"	21
# "ASN00067107"	10
# "ASN00067110"	13
# "ASN00067118"	15
# "ASN00068001"	88
# "ASN00068009"	106
# "ASN00068012"	29
# "ASN00068023"	129
# "ASN00068034"	245
# "ASN00068045"	369
# "ASN00068056"	24
# "ASN00068067"	36
# "ASN00068070"	47
# "ASN00068078"	24
# "ASN00068081"	102
# "ASN00068089"	189
# "ASN00068092"	9
# "ASN00068100"	90
# "ASN00068108"	255
# "ASN00068111"	22
# "ASN00068119"	21
# "ASN00068122"	89
# "ASN00068133"	23
# "ASN00068144"	30
# "ASN00068155"	25
# "ASN00068166"	55
# "ASN00068177"	100
# "ASN00068188"	153
# "ASN00068191"	9
# "ASN00068199"	60
# "ASN00068207"	123
# "ASN00068210"	29
# "ASN00068218"	80
# "ASN00068229"	137
# "ASN00068243"	25
# "ASN00068254"	26
# "ASN00069002"	270
# "ASN00069013"	318
# "ASN00069024"	301
# "ASN00069035"	12
# "ASN00069046"	7
# "ASN00069057"	46
# "ASN00069060"	55
# "ASN00069068"	44
# "ASN00069071"	39
# "ASN00069079"	26
# "ASN00069082"	20
# "ASN00085004"	49
# "ASN00085015"	219
# "ASN00085026"	209
# "ASN00085037"	50
# "ASN00085040"	209
# "ASN00085048"	55
# "ASN00085051"	134
# "ASN00085059"	302
# "ASN00085062"	254
# "ASN00085073"	152
# "ASN00085084"	306
# "ASN00085095"	57
# "ASN00085103"	107
# "ASN00085114"	69
# "ASN00085125"	17
# "ASN00085136"	14
# "ASN00085147"	9
# "ASN00085150"	56
# "ASN00085158"	10
# "ASN00085161"	5
# "ASN00085169"	13
# "ASN00085183"	104
# "ASN00085194"	50
# "ASN00085202"	85
# "ASN00085213"	7
# "ASN00085224"	18
# "ASN00085235"	14
# "ASN00085246"	23
# "ASN00085268"	17
# "ASN00085271"	2
# "ASN00085279"	113
# "ASN00085282"	265
# "ASN00085293"	79
# "ASN00086005"	90
# "ASN00086016"	151
# "ASN00086027"	233
# "ASN00086038"	177
# "ASN00086041"	85
# "ASN00086049"	66
# "ASN00086052"	61
# "ASN00086063"	206
# "ASN00086074"	104
# "ASN00086085"	203
# "ASN00086096"	136
# "ASN00086104"	209
# "ASN00086115"	61
# "ASN00086126"	26
# "ASN00086137"	42
# "ASN00086140"	27
# "ASN00086148"	65
# "ASN00086151"	44
# "ASN00086162"	15
# "ASN00086173"	35
# "ASN00086184"	10
# "ASN00086195"	16
# "ASN00086203"	19
# "ASN00086214"	15
# "ASN00086225"	15
# "ASN00086236"	7
# "ASN00086247"	101
# "ASN00086250"	101
# "ASN00086258"	31
# "ASN00086261"	154
# "ASN00086269"	72
# "ASN00086272"	5
# "ASN00086283"	56
# "ASN00086294"	14
# "ASN00086302"	2
# "ASN00086313"	97
# "ASN00086324"	106
# "ASN00086346"	20
# "ASN00086357"	72
# "ASN00086360"	64
# "ASN00086368"	26
# "ASN00086371"	44
# "ASN00086379"	49
# "ASN00086382"	28
# "ASN00086393"	64
# "ASN00087006"	336
# "ASN00087017"	198
# "ASN00087020"	220
# "ASN00087028"	54
# "ASN00087031"	212
# "ASN00087039"	260
# "ASN00087042"	278
# "ASN00087053"	319
# "ASN00087064"	67
# "ASN00087075"	106
# "ASN00087086"	39
# "ASN00087097"	21
# "ASN00087105"	33
# "ASN00087116"	26
# "ASN00087130"	162
# "ASN00087138"	1
# "ASN00087141"	101
# "ASN00087149"	19
# "ASN00087163"	78
# "ASN00087174"	56
# "ASN00088007"	212
# "ASN00088010"	12
# "ASN00088018"	100
# "ASN00088021"	112
# "ASN00088029"	361
# "ASN00088032"	169
# "ASN00088043"	328
# "ASN00088054"	214
# "ASN00088065"	136
# "ASN00088076"	7
# "ASN00088087"	24
# "ASN00088090"	8
# "ASN00088098"	19
# "ASN00088106"	13
# "ASN00088117"	80
# "ASN00088120"	94
# "ASN00088128"	4
# "ASN00088131"	174
# "ASN00088142"	5
# "ASN00088153"	154
# "ASN00088164"	51
# "ASN00089000"	210
# "ASN00089008"	44
# "ASN00089011"	319
# "ASN00089019"	295
# "ASN00089022"	192
# "ASN00089033"	344
# "ASN00089044"	28
# "ASN00089055"	17
# "ASN00095025"	62
# "ASN00095036"	49
# "ASN00095047"	56
# "ASN00095061"	45
# "ASN00095069"	60
# "ASN00095072"	41
# "ASN00096004"	119
# "ASN00096015"	141
# "ASN00096026"	58
# "ASN00096037"	21
# "ASN00096040"	10
# "ASN00096048"	8
# "ASN00096051"	80
# "ASN00096059"	12
# "ASN00096062"	14
# "ASN00097005"	27
# "ASN00097016"	112
# "ASN00097038"	34
# "ASN00097041"	48
# "ASN00097049"	77
# "ASN00097074"	40
# "ASN00097085"	59
# "ASN00098006"	91
# "ASN00098017"	141
# "ASN00098020"	44
# "ASN00099007"	92
# "ASN00099010"	77
# "ASN00099018"	37
# "ASN00099021"	54
# "AU000015410"	444
# "AYW00067401"	34
# "AYW00086101"	82
# "BC000068226"	99
# "BDW00013602"	252
# "BFW00012713"	89
# "BL000085365"	91
# "BOM00026645"	193
# "BOM00026832"	203
# "BOM00026887"	182
# "BOM00033036"	191
# "BOM00033124"	119
# "BR000047006"	12
# "BR000052000"	31
# "BR000063000"	24
# "BR000083361"	60
# "BR000083743"	47
# "BR000147007"	25
# "BR000147010"	20
# "BR000147018"	13
# "BR000148011"	21
# "BR000151000"	20
# "BR000154003"	10
# "BR000159000"	13
# "BR000162000"	23
# "BR000247000"	28
# "BR000248001"	18
# "BR000249002"	19
# "BR000250000"	22
# "BR000260007"	17
# "BR000261000"	19
# "BR000269000"	20
# "BR000338014"	31
# "BR000347001"	21
# "BR000351002"	19
# "BR000361001"	18
# "BR000362002"	16
# "BR000442005"	27
# "BR000443006"	32
# "BR000445008"	17
# "BR000446001"	16
# "BR000447002"	13
# "BR000456000"	18
# "BR000467000"	13
# "BR000468001"	11
# "BR000469002"	13
# "BR000536036"	14
# "BR000537037"	14
# "BR000539053"	9
# "BR000543010"	38
# "BR000555000"	19
# "BR000560002"	6
# "BR000566000"	15
# "BR000567001"	19
# "BR000643011"	18
# "BR000644012"	30
# "BR000645002"	17
# "BR000655001"	21
# "BR000735158"	14
# "BR000736041"	13
# "BR000737006"	90
# "BR000742011"	18
# "BR000743009"	18
# "BR000745003"	38
# "BR000835137"	14
# "BR000835140"	11
# "BR000838000"	66
# "BR000839034"	23
# "BR000840010"	37
# "BR000845004"	16
# "BR000846005"	16
# "BR000852000"	12
# "BR000948000"	26
# "BR000949001"	22
# "BR000951000"	12
# "BR000962000"	16
# "BR000963001"	21
# "BR001036005"	65
# "BR001036063"	9
# "BR001038007"	24
# "BR001055002"	18
# "BR001058005"	13
# "BR001137043"	8
# "BR001140010"	34
# "BR001140032"	15
# "BR001143002"	52
# "BR001144014"	28
# "BR001145004"	47
# "BR001149000"	22
# "BR001152000"	19
# "BR001164001"	12
# "BR001237000"	29
# "BR001238045"	20
# "BR001241001"	31
# "BR001244015"	14
# "BR001245005"	28
# "BR001248000"	32
# "BR001249001"	22
# "BR001251000"	16
# "BR001262000"	17
# "BR001344016"	23
# "BR001346007"	22
# "BR001347000"	26
# "BR001348001"	27
# "BR001349002"	21
# "BR001350000"	22
# "BR001352002"	13
# "BR001359001"	15
# "BR001444006"	7
# "BR001444017"	53
# "BR001446000"	12
# "BR001447001"	27
# "BR001448002"	27
# "BR001449003"	12
# "BR001450001"	22
# "BR001455006"	8
# "BR001456010"	16
# "BR001457000"	31
# "BR001539016"	31
# "BR001540003"	35
# "BR001542016"	18
# "BR001544018"	28
# "BR001544021"	17
# "BR001544032"	9
# "BR001546001"	28
# "BR001547002"	22
# "BR001548003"	48
# "BR001549004"	22
# "BR001550002"	22
# "BR001551003"	22
# "BR001554006"	36
# "BR001555007"	19
# "BR001556000"	30
# "BR001557001"	28
# "BR001642028"	9
# "BR001643018"	26
# "BR001645009"	25
# "BR001647003"	23
# "BR001650003"	27
# "BR001655000"	21
# "BR001656001"	21
# "BR001657002"	24
# "BR001739010"	48
# "BR001739021"	9
# "BR001740005"	49
# "BR001741006"	40
# "BR001744009"	56
# "BR001744012"	26
# "BR001744034"	10
# "BR001748005"	28
# "BR001750004"	29
# "BR001752006"	24
# "BR001754000"	35
# "BR001755001"	24
# "BR001756002"	18
# "BR001839000"	47
# "BR001840006"	26
# "BR001840017"	31
# "BR001840020"	20
# "BR001841007"	38
# "BR001841010"	31
# "BR001841018"	25
# "BR001841021"	8
# "BR001842000"	25
# "BR001842008"	32
# "BR001843001"	22
# "BR001843012"	17
# "BR001845014"	43
# "BR001846004"	23
# "BR001846015"	39
# "BR001847005"	15
# "BR001848006"	27
# "BR001853000"	33
# "BR001854001"	26
# "BR001940007"	53
# "BR001940010"	47
# "BR001940018"	31
# "BR001940021"	31
# "BR001941000"	60
# "BR001941008"	55
# "BR001941011"	31
# "BR001941019"	18
# "BR001942001"	47
# "BR001942009"	12
# "BR001943002"	59
# "BR001943013"	17
# "BR001943024"	58
# "BR001943035"	46
# "BR001945004"	42
# "BR001945037"	18
# "BR001946005"	56
# "BR001947006"	34
# "BR001948007"	25
# "BR001948010"	9
# "BR001949000"	18
# "BR001952000"	15
# "BR001953001"	16
# "BR001954002"	26
# "BR001956004"	31
# "BR001957005"	18
# "BR002040005"	53
# "BR002040016"	7
# "BR002040038"	14
# "BR002041017"	45
# "BR002041020"	38
# "BR002042007"	17
# "BR002042010"	60
# "BR002042018"	26
# "BR002043008"	25
# "BR002043011"	60
# "BR002043019"	9
# "BR002043022"	26
# "BR002044009"	59
# "BR002044012"	56
# "BR002044023"	15
# "BR002044045"	6
# "BR002045002"	58
# "BR002045013"	26
# "BR002046025"	13
# "BR002047037"	30
# "BR002048041"	15
# "BR002049031"	7
# "BR002052006"	15
# "BR002055001"	24
# "BR002141007"	49
# "BR002142000"	53
# "BR002142008"	23
# "BR002142019"	30
# "BR002142022"	53
# "BR002143001"	51
# "BR002143009"	42
# "BR002143012"	109
# "BR002144002"	59
# "BR002144013"	25
# "BR002144024"	33
# "BR002145014"	7
# "BR002146026"	55
# "BR002148053"	56
# "BR002153000"	27
# "BR002154001"	27
# "BR002157004"	23
# "BR002242001"	35
# "BR002242012"	34
# "BR002242023"	40
# "BR002243002"	49
# "BR00E3-2240"	26
# "BR00E3-2350"	10
# "BR00E3-2460"	26
# "BR00E3-2570"	17
# "BR00E3-2600"	14
# "BR00E4-0030"	14
# "BR00E4-0250"	59
# "BR00E4-0360"	59
# "BR00E4-0470"	59
# "BR00E4-0500"	55
# "BR00E4-0610"	16
# "BR00E4-1350"	26
# "BR00E5-0020"	12
# "BR00E5-0130"	34
# "BR00E5-0350"	32
# "BR00E5-0460"	50
# "BR00E5-0600"	28
# "BR00E5-0680"	27
# "BR00E5-0710"	26
# "BR00E6-0010"	35
# "BR00E6-0120"	55
# "BR00E6-0230"	22
# "BR00E6-0340"	27
# "BR00F3-0050"	60
# "BR00F4-0040"	39
# "BR00F4-0150"	58
# "BR00F4-0260"	45
# "BR00F4-0370"	37
# "BR00F4-0400"	31
# "BR00F4-0480"	31
# "BR00F5-0030"	8
# "BR00F5-0140"	38
# "BR00F5-0360"	29
# "BR026372610"	10
# "BR026590850"	19
# "BR027409410"	19
# "BR027504340"	19
# "BR027663290"	22
# "BR027665740"	22
# "BR027669890"	22
# "BR027677480"	22
# "BR027682350"	58
# "BR027684660"	22
# "BR027699040"	57
# "BR027753740"	22
# "BR027761550"	22
# "BR027762430"	17
# "BR027763170"	20
# "BR027788250"	70
# "BR027797960"	51
# "BR027832470"	19
# "BR027870120"	22
# "BR027975830"	12
# "BR027981080"	27
# "BR027983530"	22
# "BR027984160"	54
# "BR028700840"	58
# "BR028724350"	16
# "BR028818950"	49
# "BR028834350"	22
# "BR028905410"	22
# "BR028911680"	47
# "BR028914070"	23
# "BR028917260"	22
# "BR028929720"	23
# "BR028939590"	23
# "BR028941050"	22
# "BR028944130"	52
# "BR036083850"	11
# "BR036161480"	19
# "BR036274090"	19
# "BR036454520"	9
# "BR036490050"	20
# "BR036764580"	19
# "BR036769280"	18
# "BR036873620"	19
# "BR037041370"	131
# "BR037059270"	21
# "BR037066890"	70
# "BR037097360"	64
# "BR037114270"	19
# "BR037134540"	19
# "BR037160170"	22
# "BR037166080"	22
# "BR037180990"	22
# "BR037192180"	48
# "BR037245310"	71
# "BR037342660"	22
# "BR037396450"	23
# "BR037399310"	51
# "BR037501580"	22
# "BR037588260"	22
# "BR037591620"	22
# "BR037745560"	22
# "BR037758430"	22
# "BR037771190"	15
# "BR037778230"	22
# "BR037780020"	9
# "BR037792560"	39
# "BR037843930"	22
# "BR037897030"	111
# "BR037942820"	21
# "BR037999550"	50
# "BR038004060"	22
# "BR038010360"	49
# "BR038017370"	62
# "BR038025290"	14
# "BR038032250"	13
# "BR038044680"	22
# "BR038049410"	24
# "BR038056890"	19
# "BR038062750"	26
# "BR038087250"	44
# "BR038094070"	74
# "BR038100780"	50
# "BR038103390"	52
# "BR038116150"	33
# "BR038124650"	22
# "BR038130480"	22
# "BR038135320"	53
# "BR038145190"	60
# "BR038149620"	22
# "BR038150640"	22
# "BR038157320"	25
# "BR038162160"	24
# "BR038174510"	42
# "BR038177450"	54
# "BR038191560"	21
# "BR038207120"	23
# "BR038212070"	42
# "BR038243090"	22
# "BR038253460"	18
# "BR038271310"	51
# "BR038285690"	22
# "BR038291550"	71
# "BR038295620"	12
# "BR038297790"	72
# "BR038312390"	48
# "BR038313520"	23
# "BR038320890"	51
# "BR038325590"	10
# "BR038328090"	55
# "BR038338350"	48
# "BR038348940"	61
# "BR038370280"	70
# "BR038396790"	72
# "BR038402480"	31
# "BR038414250"	72
# "BR038415710"	71
# "BR038425470"	23
# "BR038428440"	13
# "BR038431660"	50
# "BR038435370"	51
# "BR038439190"	22
# "BR038447030"	22
# "BR038451130"	22
# "BR038452890"	22
# "BR038469690"	22
# "BR038475550"	43
# "BR038476980"	19
# "BR038493840"	44
# "BR038503460"	22
# "BR038504780"	22
# "BR038510750"	68
# "BR038514350"	22
# "BR038518390"	49
# "BR038521970"	74
# "BR038536790"	59
# "BR038539430"	63
# "BR038556260"	22
# "BR038562780"	22
# "BR038564980"	53
# "BR038577270"	22
# "BR038579610"	22
# "BR038588050"	60
# "BR038591630"	21
# "BR038611150"	22
# "BR038621050"	22
# "BR038630760"	22
# "BR038641320"	22
# "BR038653970"	22
# ...
# "USC00455704"	538
# "USC00455946"	803
# "USC00456073"	163
# "USC00456381"	72
# "USC00456400"	49
# "USC00456477"	67
# "USC00456642"	14
# "USC00456763"	356
# "USC00456851"	6
# "USC00456914"	201
# "USC00457038"	481
# "USC00457247"	33
# "USC00457379"	257
# "USC00457478"	548
# "USC00457522"	164
# "USC00457544"	223
# "USC00457654"	14
# "USC00457690"	284
# "USC00457786"	18
# "USC00458688"	6
# "USC00458718"	55
# "USC00458729"	21
# "USC00458927"	8
# "USC00458930"	57
# "USC00459021"	335
# "USC00459090"	40
# "USC00459238"	867
# "USC00460580"	760
# "USC00460687"	568
# "USC00460926"	14
# "USC00461075"	234
# "USC00461196"	37
# "USC00461204"	191
# "USC00461215"	453
# "USC00461325"	19
# "USC00461358"	15
# "USC00461677"	827
# "USC00461798"	35
# "USC00461806"	46
# "USC00462054"	752
# "USC00462920"	1147
# "USC00463932"	169
# "USC00464045"	51
# "USC00464397"	351
# "USC00464430"	6
# "USC00464559"	294
# "USC00465002"	454
# "USC00465365"	526
# "USC00465453"	116
# "USC00465563"	635
# "USC00465626"	447
# "USC00465747"	115
# "USC00465871"	317
# "USC00465970"	5
# "USC00466168"	160
# "USC00466212"	627
# "USC00466674"	136
# "USC00466960"	128
# "USC00466982"	601
# "USC00467004"	431
# "USC00467444"	68
# "USC00467455"	149
# "USC00467598"	153
# "USC00467730"	894
# "USC00467785"	888
# "USC00467884"	31
# "USC00468409"	59
# "USC00468522"	102
# "USC00468580"	68
# "USC00469086"	349
# "USC00469336"	217
# "USC00469482"	186
# "USC00470268"	11
# "USC00470565"	155
# "USC00470642"	51
# "USC00470851"	167
# "USC00470950"	13
# "USC00471250"	7
# "USC00471283"	80
# "USC00471360"	22
# "USC00471618"	115
# "USC00471676"	647
# "USC00471720"	3
# "USC00472240"	367
# "USC00472314"	453
# "USC00472413"	12
# "USC00472556"	579
# "USC00472839"	994
# "USC00472842"	42
# "USC00472996"	304
# "USC00473021"	134
# "USC00473090"	36
# "USC00473186"	623
# "USC00473461"	28
# "USC00473560"	16
# "USC00473780"	13
# "USC00473917"	230
# "USC00474080"	560
# "USC00474110"	8
# "USC00474190"	12
# "USC00474396"	18
# "USC00474404"	190
# "USC00474770"	21
# "USC00475012"	41
# "USC00475298"	354
# "USC00475364"	867
# "USC00475474"	629
# "USC00475573"	493
# "USC00476200"	719
# "USC00476208"	969
# "USC00476280"	241
# "USC00476398"	836
# "USC00476420"	38
# "USC00476750"	61
# "USC00476772"	523
# "USC00476970"	10
# "USC00477113"	928
# "USC00477182"	17
# "USC00477209"	511
# "USC00477319"	110
# "USC00477869"	63
# "USC00478639"	35
# "USC00478969"	45
# "USC00479052"	30
# "USC00479236"	742
# "USC00479335"	763
# "USC00480050"	4
# "USC00480094"	10
# "USC00480124"	58
# "USC00480245"	39
# "USC00480270"	758
# "USC00480377"	12
# "USC00480380"	249
# "USC00480432"	15
# "USC00480443"	119
# "USC00480498"	68
# "USC00480528"	174
# "USC00480605"	444
# "USC00480737"	22
# "USC00480740"	487
# "USC00481172"	53
# "USC00481400"	16
# "USC00481565"	459
# "USC00481730"	754
# "USC00481752"	48
# "USC00481840"	654
# "USC00482580"	470
# "USC00482610"	358
# "USC00482995"	521
# "USC00483031"	531
# "USC00483064"	42
# "USC00483570"	315
# "USC00483930"	111
# "USC00483952"	49
# "USC00484065"	873
# "USC00484131"	3
# "USC00484205"	4
# "USC00484230"	39
# "USC00484315"	80
# "USC00484546"	10
# "USC00484700"	219
# "USC00484799"	44
# "USC00484920"	171
# "USC00485055"	557
# "USC00485088"	213
# "USC00485165"	36
# "USC00485374"	79
# "USC00485385"	17
# "USC00485525"	491
# "USC00485734"	154
# "USC00485770"	714
# "USC00485833"	90
# "USC00486081"	81
# "USC00486122"	47
# "USC00486430"	197
# "USC00486595"	458
# "USC00486603"	44
# "USC00486845"	516
# "USC00487060"	24
# "USC00487079"	173
# "USC00487200"	535
# "USC00487376"	391
# "USC00487420"	185
# "USC00487530"	88
# "USC00488003"	16
# "USC00488025"	18
# "USC00488124"	312
# "USC00488157"	66
# "USC00488160"	1124
# "USC00488209"	360
# "USC00488410"	21
# "USC00488748"	155
# "USC00488858"	441
# "USC00489150"	48
# "USC00489925"	666
# "USC00500040"	62
# "USC00500125"	70
# "USC00500172"	79
# "USC00500235"	17
# "USC00500260"	113
# "USC00500279"	84
# "USC00500433"	134
# "USC00500653"	39
# "USC00500804"	103
# "USC00501225"	26
# "USC00501269"	277
# "USC00501492"	306
# "USC00501629"	29
# "USC00501926"	377
# "USC00502105"	66
# "USC00502149"	334
# "USC00502347"	33
# "USC00502350"	187
# "USC00502457"	469
# "USC00502493"	15
# "USC00502707"	493
# "USC00502952"	146
# "USC00503205"	123
# "USC00503252"	34
# "USC00503304"	368
# "USC00503502"	128
# "USC00503667"	11
# "USC00503670"	189
# "USC00503821"	153
# "USC00504107"	90
# "USC00504110"	137
# "USC00504165"	39
# "USC00504206"	30
# "USC00504550"	237
# "USC00504701"	23
# "USC00504929"	88
# "USC00504943"	19
# "USC00505364"	13
# "USC00505397"	91
# "USC00505562"	6
# "USC00505735"	35
# "USC00505757"	270
# "USC00505845"	51
# "USC00505878"	43
# "USC00505889"	20
# "USC00506093"	12
# "USC00506769"	82
# "USC00506783"	40
# "USC00506824"	31
# "USC00506871"	185
# "USC00507281"	46
# "USC00507421"	105
# "USC00507465"	62
# "USC00507850"	29
# "USC00507902"	21
# "USC00508114"	104
# "USC00508183"	154
# "USC00508389"	92
# "USC00508400"	152
# "USC00508466"	10
# "USC00508477"	13
# "USC00508488"	28
# "USC00508532"	66
# "USC00508554"	125
# "USC00508727"	110
# "USC00508785"	18
# "USC00508815"	74
# "USC00508884"	72
# "USC00509005"	92
# "USC00509038"	9
# "USC00509085"	25
# "USC00509313"	412
# "USC00509489"	192
# "USC00509511"	148
# "USC00509690"	72
# "USC00509915"	12
# "USC00510300"	110
# "USC00510344"	54
# "USC00510740"	54
# "USC00510836"	18
# "USC00510935"	306
# "USC00511004"	496
# "USC00511125"	352
# "USC00511370"	65
# "USC00511488"	76
# "USC00511914"	207
# "USC00511925"	20
# "USC00511958"	20
# "USC00512151"	240
# "USC00512225"	102
# "USC00512566"	48
# "USC00512580"	68
# "USC00512896"	407
# "USC00513130"	237
# "USC00513369"	220
# "USC00513556"	20
# "USC00513754"	109
# "USC00514568"	202
# "USC00514634"	196
# "USC00514645"	85
# "USC00514670"	325
# "USC00514766"	246
# "USC00514829"	54
# "USC00514887"	59
# "USC00514928"	246
# "USC00515000"	315
# "USC00515011"	402
# "USC00515275"	262
# "USC00515286"	566
# "USC00515330"	197
# "USC00515404"	325
# "USC00515462"	9
# "USC00515525"	57
# "USC00515756"	57
# "USC00515781"	72
# "USC00515789"	31
# "USC00515792"	46
# "USC00515800"	186
# "USC00516012"	242
# "USC00516122"	295
# "USC00516144"	141
# "USC00516180"	19
# "USC00516537"	38
# "USC00516933"	301
# "USC00517541"	23
# "USC00517857"	135
# "USC00518407"	173
# "USC00518553"	61
# "USC00518638"	116
# "USC00518652"	163
# "USC00518968"	20
# "USC00519510"	76
# "USC00519521"	192
# "USC00519738"	399
# "USC00914278"	86
# "USR0000ACHF"	24
# "USR0000ADVK"	28
# "USR0000AFLG"	46
# "USR0000AFOR"	16
# "USR0000AGEO"	28
# "USR0000AHLM"	30
# "USR0000AHPI"	22
# "USR0000AINN"	50
# "USR0000ALIV"	30
# "USR0000AMOS"	42
# "USR0000ANOR"	42
# "USR0000AOAK"	42
# "USR0000AOKM"	30
# "USR0000APAR"	38
# "USR0000APLE"	32
# "USR0000ARUT"	26
# "USR0000ASAG"	28
# "USR0000ASCA"	22
# "USR0000ASES"	22
# "USR0000ASKI"	26
# "USR0000ASSA"	60
# "USR0000ASTR"	44
# "USR0000ATLA"	44
# "USR0000ATTA"	20
# "USR0000CART"	56
# "USR0000CBAR"	32
# "USR0000CBEN"	38
# "USR0000CBEV"	32
# "USR0000CBIR"	20
# "USR0000CBKD"	38
# "USR0000CBLU"	42
# "USR0000CBPI"	24
# "USR0000CBRK"	28
# "USR0000CCAA"	26
# "USR0000CCOO"	56
# "USR0000CCRR"	26
# "USR0000CCRZ"	56
# "USR0000CDRA"	30
# "USR0000CDRY"	56
# "USR0000CEAG"	28
# "USR0000CEEC"	24
# "USR0000CFAN"	46
# "USR0000CFIV"	30
# "USR0000CGZF"	16
# "USR0000CHEP"	28
# "USR0000CHOR"	44
# "USR0000CJAR"	20
# "USR0000CJOH"	30
# "USR0000CJUN"	50
# "USR0000CKEE"	46
# "USR0000CLAH"	46
# "USR0000CLAP"	46
# "USR0000CLHO"	44
# "USR0000CMES"	40
# "USR0000CMIO"	24
# "USR0000CMLR"	30
# "USR0000CMOU"	28
# "USR0000CMSA"	44
# "USR0000CMTZ"	46
# "USR0000COAM"	42
# "USR0000COKG"	36
# "USR0000COKO"	34
# "USR0000CPAT"	44
# "USR0000CPIL"	40
# "USR0000CPOR"	56
# "USR0000CREF"	56
# "USR0000CSBB"	36
# "USR0000CSDD"	24
# "USR0000CSHH"	24
# "USR0000CTHO"	46
# "USR0000CTRA"	38
# "USR0000CTRI"	34
# "USR0000CUND"	22
# "USR0000CVAN"	40
# "USR0000CWEA"	16
# "USR0000CWHT"	46
# "USR0000CWWC"	56
# "USR0000FLSU"	22
# "USR0000GCAM"	24
# "USR0000GDAL"	20
# "USR0000GTAL"	24
# "USR0000GWAY"	20
# "USR0000HHAI"	24
# "USR0000HKAN"	24
# "USR0000HLUA"	24
# "USR0000HORS"	46
# "USR0000HSCH"	18
# "USR0000IBOF"	22
# "USR0000IBON"	56
# "USR0000IBRA"	46
# "USR0000IBUL"	46
# "USR0000IDER"	46
# "USR0000IGAS"	50
# "USR0000IGRL"	22
# "USR0000IHAR"	22
# "USR0000ILIN"	24
# "USR0000ILOD"	48
# "USR0000IMAU"	16
# "USR0000INOR"	26
# "USR0000IRED"	56
# "USR0000ISKI"	42
# "USR0000JENS"	60
# "USR0000KKOO"	22
# "USR0000KTRI"	22
# "USR0000LAVA"	36
# "USR0000LSAB"	16
# "USR0000MBAD"	22
# "USR0000MBAL"	20
# "USR0000MBRE"	56
# "USR0000MCBT"	24
# "USR0000MCYC"	48
# "USR0000MEFF"	20
# "USR0000MENN"	24
# "USR0000MH41"	30
# "USR0000MHEB"	24
# "USR0000MHOT"	44
# "USR0000MLIB"	24
# "USR0000MLRC"	20
# "USR0000MMCK"	20
# "USR0000MMOO"	24
# "USR0000MPIN"	28
# "USR0000MPOL"	20
# "USR0000MRDG"	26
# "USR0000MTEN"	18
# "USR0000MUSK"	22
# "USR0000MZOR"	52
# "USR0000NBEA"	48
# "USR0000NCAT"	56
# "USR0000NCRE"	28
# "USR0000NFAI"	18
# "USR0000NFBR"	26
# "USR0000NHIG"	20
# "USR0000NKYL"	30
# "USR0000NORI"	54
# "USR0000NROC"	46
# "USR0000NSTO"	20
# "USR0000NTEW"	22
# "USR0000NTOQ"	18
# "USR0000NUWH"	20
# "USR0000NWMT"	20
# "USR0000OANT"	38
# "USR0000OBLA"	56
# "USR0000OBRO"	46
# "USR0000OBUR"	42
# "USR0000OCAM"	32
# "USR0000OCHL"	22
# "USR0000OGLD"	12
# "USR0000OGOO"	56
# "USR0000OPRI"	18
# "USR0000OREB"	56
# "USR0000OSQU"	56
# "USR0000OTIL"	32
# "USR0000OTUP"	56
# "USR0000PARI"	18
# "USR0000SANP"	32
# "USR0000SMAG"	52
# "USR0000TANA"	24
# "USR0000TBAS"	20
# "USR0000TCHI"	26
# "USR0000TCLM"	20
# "USR0000TDAY"	20
# "USR0000THAM"	20
# "USR0000TKIR"	24
# "USR0000TLAY"	20
# "USR0000TLBJ"	26
# "USR0000TOMB"	30
# "USR0000TPOS"	26
# "USR0000TSAB"	22
# "USR0000TSBS"	26
# "USR0000TSHI"	20
# "USR0000VASH"	30
# "USR0000VELM"	28
# "USR0000VJAM"	32
# "USR0000VMAR"	20
# "USR0000WAND"	50
# "USR0000WANT"	28
# "USR0000WBLA"	20
# "USR0000WBRO"	40
# "USR0000WBUR"	42
# "USR0000WCAM"	50
# "USR0000WDDG"	32
# "USR0000WFIR"	56
# "USR0000WGLD"	16
# "USS0005J10S"	147
# "USS0005J18S"	138
# "USS0005K06S"	148
# "USS0005K28S"	79
# "USS0005P09S"	70
# "USS0006H13S"	134
# "USS0006H24S"	55
# "USS0006J19S"	55
# "USS0006K10S"	110
# "USS0006K43S"	79
# "USS0006N04S"	140
# "USS0007E06S"	140
# "USS0007H03S"	134
# "USS0007K11S"	134
# "USS0007M31S"	130
# "USS0008M07S"	142
# "USS0008M10S"	98
# "USS0008S01S"	136
# "USS0009E08S"	148
# "USS0009E11S"	132
# "USS0009F18S"	138
# "USS0009F21S"	134
# "USS0009S02S"	114
# "USS0010C08S"	134
# "USS0010C22S"	65
# "USS0010D07S"	160
# "USS0010D10S"	55
# "USS0010E06S"	148
# "USS0010E17S"	142
# "USS0010E20S"	122
# "USS0010F16S"	142
# "USS0010G15S"	134
# "USS0010J01S"	134
# "USS0011C01S"	137
# "USS0011D08S"	141
# "USS0011D11S"	133
# "USS0011D19S"	112
# "USS0011D99S"	59
# "USS0011E10S"	136
# "USS0011E29S"	156
# "USS0011G05S"	136
# "USS0011G30S"	122
# "USS0011H37S"	138
# "USS0011H59S"	50
# "USS0011J02S"	142
# "USS0011J46S"	142
# "USS0011J57S"	128
# "USS0011J68S"	69
# "USS0011K09S"	141
# "USS0012B14S"	157
# "USS0012C13S"	148
# "USS0012D09S"	134
# "USS0012E08S"	142
# "USS0012G17S"	147
# "USS0012L12S"	134
# "USS0013A27S"	149
# "USS0013C03S"	142
# "USS0013E23S"	139
# "USS0014B05S"	65
# "USS0014C04S"	142
# "USS0014F12S"	134
# "USS0015C16S"	138
# "USS0015J06S"	126
# "USS0016A08S"	137
# "USS0016C20S"	144
# "USS0017A01S"	130
# "USS0017D06S"	138
# "USS0017H02S"	136
# "VE000005011"	29
# "VE000005484"	71
# "VE000009408"	28
# "VMW00041009"	28
# "VMW00041023"	29
# "VMW00041034"	16
# "VMW00041045"	2
# "VMW00041056"	42
# "VQC00671620"	15
# "VQC00672830"	33
# "VQC00673677"	100
# "VQW00011624"	490
# "WA002783020"	16
# "WA003490820"	19
# "WA003805190"	14
# "WA003826120"	17
# "WA003840230"	18
# "WA003852330"	21
# "WA003855160"	21
# "WA004192150"	17
# "WA005318490"	15
# "WA005656660"	19
# "WA005700880"	20
# "WA006127710"	17
# "WA006508360"	17
# "WA006555030"	23
# "WA006567710"	17
# "WA006964920"	18
# "WA007010240"	17
# "WA007384350"	16
# "WA007400630"	17
# "WA007423480"	20
# "WA007821460"	17
# "WA007827040"	22
# "WA007847200"	16
# "WA007868650"	17
# "WA007877120"	17
# "WA008227940"	18
# "WA008261490"	15
# "WA008332220"	19
# "WA008714110"	17
# "WA008751070"	18
# "WA009156230"	17
# "WA009585120"	13
# "WA010066890"	15
# "WA010082900"	15
# "WA010101180"	18
# "WA010107010"	13
# "WA010517310"	92
# "WA010542310"	17
# "WA010558090"	20
# "WA010574650"	17
# "WA010576160"	17
# "WA011021610"	18
# "WA011037970"	17
# "WA012011470"	20
# "WA012064960"	17
# "WF000917530"	78
# "WQW00041606"	721
# "WZ004094600"	85
# "WZ004834260"	74
# "ZA000067543"	30
# "ZA000067741"	38
# "ZI000067969"	87
# "ZI000067983"	186

# %% [markdown]
# ## Two useful command-line utilities

# %% [markdown]
# the mrjob command line depends on the same configuration file as the run-time library. This configuration file is, by default, located at ~/.mrjob.conf

# %%
# !mrjob
# Out:
# usage: mrjob {subcommand|--help}"
#
# subcommands:
#   audit-emr-usage:          Audit EMR usage
#   create-job-flow:          Create an EMR job flow
#   fetch-logs:               Fetch and parse EMR logs for errors and counters
#   report-long-jobs:         Report EMR jobs which have been running for a long time
#   run:                      Run a job
#   s3-tmpwatch:              Delete S3 keys older than a specified time
#   terminate-idle-job-flows: Terminate idle EMR job flows
#   terminate-job-flow:       Terminate a single EMR job flow

# %%
# !mrjob audit-emr-usage
# Out:
# getting job flow history...
# using configs in /home/ubuntu/.mrjob.conf
# creating new scratch bucket mrjob-075a8c88c3bb40c0
# using s3://mrjob-075a8c88c3bb40c0/tmp/ as our scratch dir on S3
# compiling job flow stats...
# Total  # of Job Flows: 22
#
# * All times are in UTC.
#
# Min create time: 2014-05-04 05:33:15
# Max create time: 2014-05-17 08:07:39
#    Current time: 2014-05-19 22:47:45
#
# * All usage is measured in Normalized Instance Hours, which are
#   roughly equivalent to running an m1.small instance for an hour.
#   Billing is estimated, and may not match Amazon's system exactly.
#
# Total billed:   10810.99  100.0%
#   Total used:     309.40    2.9%
#     bootstrap:     10.64    0.1%
#     jobs:         298.76    2.8%
#   Total waste:  10501.60   97.1%
#     at end:      2285.58   21.1%
#     other:       8216.02   76.0%
#
# Daily statistics:
#
#  date          billed      used     waste   % waste
#  2014-05-19   1489.22    133.06   1356.16      91.1
#  2014-05-18   1567.88     47.51   1520.37      97.0
#       88.96 Stations_Statistics
#       16.04 geo_4meas
#       14.08 station_stats
#        6.65 geo_bins
#        6.19 no_script
#        6.18 good_counts
#        6.13 spatiald
#        5.27 None
#        4.03 check_for_dupes
#        3.81 mr_word_freq_count
#        3.46 mr_most_used_word
#        3.20 variable_counts
#        1.42 hw_step_1
#        1.36 mr_weather_count_measurements
#        1.30 weather_01
#        1.23 mr_weather_HW2
#        0.09 actualWordFreqCount
#
# Top jobs, by time billed but not used:
#     5253.73 mr_weather
#     2484.13 Stations_Statistics
#     1253.68 None
#      443.02 no_script
#      266.98 station_stats
#      238.58 mr_most_used_word
#      225.40 geo_4meas
#      158.73 mr_word_freq_count
#       78.75 spatiald
#       53.36 geo_bins
#       25.02 mr_weather_count_measurements
#        8.21 mr_weather_HW2
#        3.24 weather_01
#        3.16 good_counts
#        2.58 actualWordFreqCount
#        1.80 hw_step_1
#        1.22 variable_counts
#        0.00 check_for_dupes
#
# Top users, by total time used:
#      234.52 ubuntu
#       66.14 yoavfreund
#        5.27 None
#        3.46 lige
#
# Top users, by time billed but not used:
#     6613.89 ubuntu
#     2395.44 yoavfreund
#     1253.68 None
#      238.58 lige
#
# Top job steps, by total time used (step number first):
#      139.99   1 mr_weather
#       88.96   1 Stations_Statistics
#       16.04   1 geo_4meas
#       14.08   1 station_stats
#        6.65   1 geo_bins
#        6.18   1 good_counts
#        6.13   1 spatiald
#        4.03   1 check_for_dupes
#        3.81   1 mr_word_freq_count
#        3.20   1 variable_counts
#        2.45   1 mr_most_used_word
#        1.42   1 hw_step_1
#        1.36   1 mr_weather_count_measurements
#        1.30   1 weather_01
#        1.23   1 mr_weather_HW2
#        1.01   2 mr_most_used_word
#        0.82     (non-mrjob step)
#        0.09   1 actualWordFreqCount
#
# Top job steps, by total time billed but not used (un-pooled only):
#     5253.73   1 mr_weather
#     2484.13   1 Stations_Statistics
#     1253.72     (non-mrjob step)
#      266.98   1 station_stats
#      225.40   1 geo_4meas
#      199.41   1 mr_most_used_word
#      158.73   1 mr_word_freq_count
#       78.75   1 spatiald
#       53.36   1 geo_bins
#       39.17   2 mr_most_used_word
#       25.02   1 mr_weather_count_measurements
#        8.21   1 mr_weather_HW2
#        3.24   1 weather_01
#        3.16   1 good_counts
#        2.58   1 actualWordFreqCount
#        1.80   1 hw_step_1
#        1.22   1 variable_counts
#        0.00   1 check_for_dupes
#
# All pools, by total time billed:
#    10810.99 (not pooled)
#
# All pools, by total time billed but not used:
#    10501.60 (not pooled)
#
# All job flows, by total time billed:
#     2966.01 j-262J0JTFJIRLO no_script.yoavfreund.20140516.040032.370095
#     2277.00 j-BPX1DCPJZHBT  no_script.yoavfreund.20140510.225546.168485
#     2039.98 j-1RE8D7HBISOI0 no_script.yoavfreund.20140517.080731.371759
#      825.00 j-2W5L09A1HZ3LF no_script.yoavfreund.20140511.140350.236087
#      729.00 j-2VUZQS9W11GSG no_script.yoavfreund.20140515.094754.314127
#      560.00 j-35O01QLMRUFED My cluster
#      404.00 j-1HFD8T7K9LGVH no_script.yoavfreund.20140509.131949.007708
#      402.00 j-3S4WCJPFOULKX no_script.yoavfreund.20140514.153352.424304
#      311.00 j-1L1J6A5FX0VS1 no_script.yoavfreund.20140514.175527.046789
#      231.00 j-19ZLC6D8RI1E4 My Bigger Cluster
#       42.00 j-KZSDWFOETODE  My Bigger Cluster
#       24.00 j-2DP66KPYB7NHE My Bigger Cluster
#        0.00 j-A0JHEG86PAGJ  A 6 node spot market cluster
#        0.00 j-2M58Y9QSWOIFH A 6 node spot market cluster
#        0.00 j-13O1ZEWJ0595Q A 6 node spot market cluster
#        0.00 j-1BCZIG7KD2S0K My Bigger Cluster
#        0.00 j-6ZU44Z9AXTQ3  My Bigger Cluster
#        0.00 j-2E4BUM0ADD3MX My Bigger Cluster
#        0.00 j-T3YBEP46V2EF  mr_word_freq_count.yoavfreund.20140511.164224.550664
#        0.00 j-1Q73Z9BEPMK8Q no_script.yoavfreund.20140514.052614.527640
#        0.00 j-CA484CR30BXC  no_script.yoavfreund.20140514.140811.019418
#        0.00 j-2S9FP036YSB2B no_script.yoavfreund.20140514.170443.716561
#
# All job flows, by time billed but not used:
#     2782.91 j-262J0JTFJIRLO no_script.yoavfreund.20140516.040032.370095
#     2237.71 j-BPX1DCPJZHBT  no_script.yoavfreund.20140510.225546.168485
#     1994.19 j-1RE8D7HBISOI0 no_script.yoavfreund.20140517.080731.371759
#      824.26 j-2W5L09A1HZ3LF no_script.yoavfreund.20140511.140350.236087
#      723.21 j-2VUZQS9W11GSG no_script.yoavfreund.20140515.094754.314127
#      556.78 j-35O01QLMRUFED My cluster
#      396.89 j-3S4WCJPFOULKX no_script.yoavfreund.20140514.153352.424304
#      385.41 j-1HFD8T7K9LGVH no_script.yoavfreund.20140509.131949.007708
#      306.18 j-1L1J6A5FX0VS1 no_script.yoavfreund.20140514.175527.046789
#      229.91 j-19ZLC6D8RI1E4 My Bigger Cluster
#       41.31 j-KZSDWFOETODE  My Bigger Cluster
#       22.83 j-2DP66KPYB7NHE My Bigger Cluster
#        0.00 j-A0JHEG86PAGJ  A 6 node spot market cluster
#        0.00 j-2M58Y9QSWOIFH A 6 node spot market cluster
#        0.00 j-13O1ZEWJ0595Q A 6 node spot market cluster
#        0.00 j-1BCZIG7KD2S0K My Bigger Cluster
#        0.00 j-6ZU44Z9AXTQ3  My Bigger Cluster
#        0.00 j-2E4BUM0ADD3MX My Bigger Cluster
#        0.00 j-T3YBEP46V2EF  mr_word_freq_count.yoavfreund.20140511.164224.550664
#        0.00 j-1Q73Z9BEPMK8Q no_script.yoavfreund.20140514.052614.527640
#        0.00 j-CA484CR30BXC  no_script.yoavfreund.20140514.140811.019418
#        0.00 j-2S9FP036YSB2B no_script.yoavfreund.20140514.170443.716561
#
# Details for all job flows:
#
#  id              state         created             steps        time ran     billed    waste   user   name
#  j-1RE8D7HBISOI0 WAITING       2014-05-17 08:07:39  22  2 days, 14:34:12     45.79   1994.19 yoavfreund no_script
#  j-262J0JTFJIRLO RUNNING       2014-05-16 04:00:42 130  3 days, 18:38:01    183.10   2782.91 yoavfreund no_script
#  j-2VUZQS9W11GSG FAILED        2014-05-15 09:48:03  55   1 day, 13:22:30      5.79    723.21 yoavfreund no_script
#  j-1L1J6A5FX0VS1 TERMINATED    2014-05-14 17:55:36  21          16:24:14      4.82    306.18 yoavfreund no_script
#  j-2S9FP036YSB2B FAILED        2014-05-14 17:04:53   1           0:20:44      0.00      0.00 yoavfreund no_script
#  j-3S4WCJPFOULKX TERMINATED    2014-05-14 15:34:01  22          18:45:52      5.11    396.89 yoavfreund no_script
#  j-CA484CR30BXC  FAILED        2014-05-14 14:08:19   1           0:01:56      0.00      0.00 yoavfreund no_script
#  j-1Q73Z9BEPMK8Q FAILED        2014-05-14 05:26:24   1           0:02:42      0.00      0.00 yoavfreund no_script
#  j-T3YBEP46V2EF  TERMINATED    2014-05-11 16:42:34   2           0:00:00      0.00      0.00 yoavfreund mr_word_freq_count
#  j-2W5L09A1HZ3LF TERMINATED    2014-05-11 14:03:59   8    1 day, 0:30:22      0.74    824.26 yoavfreund no_script
#  j-BPX1DCPJZHBT  FAILED        2014-05-10 22:55:55  87  2 days, 20:59:13     39.29   2237.71 yoavfreund no_script
#  j-1HFD8T7K9LGVH FAILED        2014-05-09 13:19:58  18          12:43:39     18.59    385.41 yoavfreund no_script
#  j-35O01QLMRUFED TERMINATED    2014-05-08 06:19:21   3          19:34:35      3.22    556.78          not started by mrjob
#  j-A0JHEG86PAGJ  FAILED        2014-05-07 00:43:12   1           0:00:00      0.00      0.00          not started by mrjob
#  j-2M58Y9QSWOIFH FAILED        2014-05-06 15:30:34   1           0:00:00      0.00      0.00          not started by mrjob
#  j-13O1ZEWJ0595Q FAILED        2014-05-06 04:52:07   1           0:00:00      0.00      0.00          not started by mrjob
#  j-1BCZIG7KD2S0K FAILED        2014-05-06 03:15:25   1           0:00:00      0.00      0.00          not started by mrjob
#  j-6ZU44Z9AXTQ3  FAILED        2014-05-06 00:29:50   1           0:00:00      0.00      0.00          not started by mrjob
#  j-2E4BUM0ADD3MX FAILED        2014-05-06 00:10:53   1           0:00:00      0.00      0.00          not started by mrjob
#  j-19ZLC6D8RI1E4 TERMINATED    2014-05-04 23:12:39   1           6:20:55      1.09    229.91          not started by mrjob
#  j-KZSDWFOETODE  TERMINATED    2014-05-04 20:09:33   1           2:45:09      0.69     41.31          not started by mrjob
#  j-2DP66KPYB7NHE TERMINATED    2014-05-04 05:33:15   1           0:19:44      1.17     22.83          not started by mrjob

# %% [markdown]
# s3cmd is a utility that makes it easy to work with s3

# %%
# !s3cmd --help
# Out:
# Usage: s3cmd [options] COMMAND [parameters]
#
# S3cmd is a tool for managing objects in Amazon S3 storage. It allows for
# making and removing "buckets" and uploading, downloading and removing
# "objects" from these buckets.
#
# Options:
#   -h, --help            show this help message and exit
#   --configure           Invoke interactive (re)configuration tool.
#   -c FILE, --config=FILE
#                         Config file name. Defaults to /home/ubuntu/.s3cfg
#   --dump-config         Dump current configuration after parsing config files
#                         and command line options and exit.
#   -n, --dry-run         Only show what should be uploaded or downloaded but
#                         don't actually do it. May still perform S3 requests to
#                         get bucket listings and other information though (only
#                         for file transfer commands)
#   -e, --encrypt         Encrypt files before uploading to S3.
#   --no-encrypt          Don't encrypt files.
#   -f, --force           Force overwrite and other dangerous operations.
#   --continue            Continue getting a partially downloaded file (only for
#                         [get] command).
#   --skip-existing       Skip over files that exist at the destination (only
#                         for [get] and [sync] commands).
#   -r, --recursive       Recursive upload, download or removal.
#   --check-md5           Check MD5 sums when comparing files for [sync].
#                         (default)
#   --no-check-md5        Do not check MD5 sums when comparing files for [sync].
#                         Only size will be compared. May significantly speed up
#                         transfer but may also miss some changed files.
#   -P, --acl-public      Store objects with ACL allowing read for anyone.
#   --acl-private         Store objects with default ACL allowing access for you
#                         only.
#   --acl-grant=PERMISSION:EMAIL or USER_CANONICAL_ID
#                         Grant stated permission to a given amazon user.
#                         Permission is one of: read, write, read_acp,
#                         write_acp, full_control, all
#   --acl-revoke=PERMISSION:USER_CANONICAL_ID
#                         Revoke stated permission for a given amazon user.
#                         Permission is one of: read, write, read_acp, wr
#                         ite_acp, full_control, all
#   --delete-removed      Delete remote objects with no corresponding local file
#                         [sync]
#   --no-delete-removed   Don't delete remote objects.
#   -p, --preserve        Preserve filesystem attributes (mode, ownership,
#                         timestamps). Default for [sync] command.
#   --no-preserve         Don't store FS attributes
#   --exclude=GLOB        Filenames and paths matching GLOB will be excluded
#                         from sync
#   --exclude-from=FILE   Read --exclude GLOBs from FILE
#   --rexclude=REGEXP     Filenames and paths matching REGEXP (regular
#                         expression) will be excluded from sync
#   --rexclude-from=FILE  Read --rexclude REGEXPs from FILE
#   --include=GLOB        Filenames and paths matching GLOB will be included
#                         even if previously excluded by one of
#                         --(r)exclude(-from) patterns
#   --include-from=FILE   Read --include GLOBs from FILE
#   --rinclude=REGEXP     Same as --include but uses REGEXP (regular expression)
#                         instead of GLOB
#   --rinclude-from=FILE  Read --rinclude REGEXPs from FILE
#   --bucket-location=BUCKET_LOCATION
#                         Datacentre to create bucket in. As of now the
#                         datacenters are: US (default), EU, us-west-1, and ap-
#                         southeast-1
#   --reduced-redundancy, --rr
#                         Store object with 'Reduced redundancy'. Lower per-GB
#                         price. [put, cp, mv]
#   --access-logging-target-prefix=LOG_TARGET_PREFIX
#                         Target prefix for access logs (S3 URI) (for [cfmodify]
#                         and [accesslog] commands)
#   --no-access-logging   Disable access logging (for [cfmodify] and [accesslog]
#                         commands)
#   -m MIME/TYPE, --mime-type=MIME/TYPE
#                         Default MIME-type to be set for objects stored.
#   -M, --guess-mime-type
#                         Guess MIME-type of files by their extension. Falls
#                         back to default MIME-Type as specified by --mime-type
#                         option
#   --add-header=NAME:VALUE
#                         Add a given HTTP header to the upload request. Can be
#                         used multiple times. For instance set 'Expires' or
#                         'Cache-Control' headers (or both) using this options
#                         if you like.
#   --encoding=ENCODING   Override autodetected terminal and filesystem encoding
#                         (character set). Autodetected: UTF-8
#   --verbatim            Use the S3 name as given on the command line. No pre-
#                         processing, encoding, etc. Use with caution!
#   --list-md5            Include MD5 sums in bucket listings (only for 'ls'
#                         command).
#   -H, --human-readable-sizes
#                         Print sizes in human readable form (eg 1kB instead of
#                         1234).
#   --progress            Display progress meter (default on TTY).
#   --no-progress         Don't display progress meter (default on non-TTY).
#   --enable              Enable given CloudFront distribution (only for
#                         [cfmodify] command)
#   --disable             Enable given CloudFront distribution (only for
#                         [cfmodify] command)
#   --cf-add-cname=CNAME  Add given CNAME to a CloudFront distribution (only for
#                         [cfcreate] and [cfmodify] commands)
#   --cf-remove-cname=CNAME
#                         Remove given CNAME from a CloudFront distribution
#                         (only for [cfmodify] command)
#   --cf-comment=COMMENT  Set COMMENT for a given CloudFront distribution (only
#                         for [cfcreate] and [cfmodify] commands)
#   --cf-default-root-object=DEFAULT_ROOT_OBJECT
#                         Set the default root object to return when no object
#                         is specified in the URL. Use a relative path, i.e.
#                         default/index.html instead of /default/index.html or
#                         s3://bucket/default/index.html (only for [cfcreate]
#                         and [cfmodify] commands)
#   -v, --verbose         Enable verbose output.
#   -d, --debug           Enable debug output.
#   --version             Show s3cmd version (1.0.0) and exit.
#   -F, --follow-symlinks
#                         Follow symbolic links as if they are regular files
#
# Commands:
#   Make bucket
#       s3cmd mb s3://BUCKET
#   Remove bucket
#       s3cmd rb s3://BUCKET
#   List objects or buckets
#       s3cmd ls [s3://BUCKET[/PREFIX]]
#   List all object in all buckets
#       s3cmd la
#   Put file into bucket
#       s3cmd put FILE [FILE...] s3://BUCKET[/PREFIX]
#   Get file from bucket
#       s3cmd get s3://BUCKET/OBJECT LOCAL_FILE
#   Delete file from bucket
#       s3cmd del s3://BUCKET/OBJECT
#   Synchronize a directory tree to S3
#       s3cmd sync LOCAL_DIR s3://BUCKET[/PREFIX] or s3://BUCKET[/PREFIX] LOCAL_DIR
#   Disk usage by buckets
#       s3cmd du [s3://BUCKET[/PREFIX]]
#   Get various information about Buckets or Files
#       s3cmd info s3://BUCKET[/OBJECT]
#   Copy object
#       s3cmd cp s3://BUCKET1/OBJECT1 s3://BUCKET2[/OBJECT2]
#   Move object
#       s3cmd mv s3://BUCKET1/OBJECT1 s3://BUCKET2[/OBJECT2]
#   Modify Access control list for Bucket or Files
#       s3cmd setacl s3://BUCKET[/OBJECT]
#   Enable/disable bucket access logging
#       s3cmd accesslog s3://BUCKET
#   Sign arbitrary string using the secret key
#       s3cmd sign STRING-TO-SIGN
#   Fix invalid file names in a bucket
#       s3cmd fixbucket s3://BUCKET[/PREFIX]
#   List CloudFront distribution points
#       s3cmd cflist
#   Display CloudFront distribution point parameters
#       s3cmd cfinfo [cf://DIST_ID]
#   Create CloudFront distribution point
#       s3cmd cfcreate s3://BUCKET
#   Delete CloudFront distribution point
#       s3cmd cfdelete cf://DIST_ID
#   Change CloudFront distribution point parameters
#       s3cmd cfmodify cf://DIST_ID
#
# For more informations see the progect homepage:
# http://s3tools.org
#
# Consider a donation if you have found s3cmd useful:
# http://s3tools.org/donate
